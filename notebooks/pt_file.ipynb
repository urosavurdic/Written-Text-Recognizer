# %%
import torch

path = "../text_recognizer/artifacts/paragraph_text_recognizer/model.pt"
checkpoint = torch.load(path, map_location="cpu")

print(checkpoint.keys())
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers'])

# %%
ckpt = torch.load(path, map_location="cpu")

print(type(ckpt))
if isinstance(ckpt, dict):
    print("Top-level keys:", ckpt.keys())
else:
    print("This file is not a dict (likely a plain state_dict).")
# Out:
# <class 'dict'>
# Top-level keys: dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers'])
